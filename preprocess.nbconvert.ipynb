# %%
import pandas as pd
import uuid

# %%
df = pd.read_csv("world_bank_preprocessed.csv")
df.head()
# Out:
#   Project ID                       Region                Country  \
# 0    P006578  Latin America and Caribbean      Republic of Chile
# 1    P006577  Latin America and Caribbean      Republic of Chile
# 2    P006578  Latin America and Caribbean      Republic of Chile
# 3    P006577  Latin America and Caribbean      Republic of Chile
# 4    P007497  Latin America and Caribbean  United Mexican States
#
#   Project Status Last Stage Reached Name                        Project Name  \
# 0         Closed                 unknown        Power and Irrigation Project
# 1         Closed          Concept Review      Agricultural Machinery Project
# 2         Closed                 unknown        Power and Irrigation Project
# 3         Closed          Concept Review      Agricultural Machinery Project
# 4         Closed         Begin Appraisal  Electric Power Development Project
#
#   Project Development Objective               Implementing Agency  \
# ...

# %%
df.columns
# Out:
# Index(['Project ID', 'Region', 'Country', 'Project Status',
#        'Last Stage Reached Name', 'Project Name',
#        'Project Development Objective ', 'Implementing Agency',
#        'Consultant Services Required', 'Project URL', 'Board Approval Date',
#        'Project Closing Date', 'Financing Type', 'Current Project Cost',
#        'IBRD Commitment ', 'IDA Commitment', 'Total IDA and IBRD Commitment',
#        'Grant Amount', 'Borrower', 'Lending Instrument',
#        'Environmental Assessment Category', 'Environmental and Social Risk',
#        'Sector 1', 'Sector 2', 'Sector 3', 'Theme 1', 'Theme 2'],
#       dtype='object')

# %%
categorical_columns = df.select_dtypes("object").columns
categorical_columns
# Out:
# Index(['Project ID', 'Region', 'Country', 'Project Status',
#        'Last Stage Reached Name', 'Project Name',
#        'Project Development Objective ', 'Implementing Agency',
#        'Consultant Services Required', 'Project URL', 'Board Approval Date',
#        'Project Closing Date', 'Financing Type', 'Borrower',
#        'Lending Instrument', 'Environmental Assessment Category',
#        'Environmental and Social Risk', 'Sector 1', 'Sector 2', 'Sector 3',
#        'Theme 1', 'Theme 2'],
#       dtype='object')

# %%
df.fillna({
    "Project ID" : "G"+str(int(uuid.uuid4().int))[-4:]+"N",      # Creates a new Project ID
    "Region" : "Unknown",
    "Country" : "Unknown",
    "Project Status" : "Unknown",
    "Last Stage Reached Name" : "Unknown",
    "Project Name" : "Unknown",
    "Project Development Objective " : "Unknown",
    "Implementing Agency" : "Unknown",
    "Consultant Services Required" : "Unknown",
    "Project URL" : "Unknown",
    "Board Approval Date" : "Unknown",
    "Project Closing Date" : "Unknown",
    "Financing Type" : "Unknown",
    "Borrower" : "Unknown",
    "Environmental and Social Risk" : "Unknown",
    "Sector 1" : "Unknown",
    "Sector 2" : "Unknown",
    "Sector 3" : "Unknown",
    "Theme 1" : "Unknown",
    "Theme 2" : "Unknown"
}, inplace=True)

# %%
df.to_csv("world_bank_preprocessed.csv", index=False)
